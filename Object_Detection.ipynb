# %% [markdown]
# <a href="https://colab.research.google.com/github/Samuelson777/Qualcomm-VisionX-Object-Detection/blob/main/Object_Detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Object Detection - [YOLO]**

# %%
# !git clone https://github.com/ultralytics/yolov5.git
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17055, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 17055 (delta 17), reused 16 (delta 8), pack-reused 17022 (from 1)
# Receiving objects: 100% (17055/17055), 15.68 MiB | 9.14 MiB/s, done.
# Resolving deltas: 100% (11711/11711), done.

# %%
# !pwd
# Out:
# /content

# %%
# %cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 887.4/887.4 kB 24.5 MB/s eta 0:00:00

# %%
# !python /content/yolov5/detect.py --weights yolov5s.pt --source /content/person.jpg
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# detect: weights=['yolov5s.pt'], source=/content/person.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-385-gb968b2d7 Python-3.10.12 torch-2.5.1+cu121 CPU
#
# ...
# 100% 14.1M/14.1M [00:00<00:00, 119MB/s]
#
# Fusing layers...
# ...

# %%
# !python /content/yolov5/detect.py --weights yolov5s.pt --source /content/selfdriving.mp4
# Out:
# detect: weights=['yolov5s.pt'], source=/content/selfdriving.mp4, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_format=0, save_csv=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# YOLOv5 🚀 v7.0-385-gb968b2d7 Python-3.10.12 torch-2.5.1+cu121 CPU
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7225885 parameters, 0 gradients, 16.4 GFLOPs
# video 1/1 (1/2804) /content/selfdriving.mp4: 384x640 1 person, 6 cars, 1 cell phone, 353.4ms
# video 1/1 (2/2804) /content/selfdriving.mp4: 384x640 1 person, 6 cars, 1 cell phone, 221.6ms
# video 1/1 (3/2804) /content/selfdriving.mp4: 384x640 1 person, 6 cars, 215.5ms
# ...
